# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd

# %%
data_df = pd.read_csv("NationalData.csv")
data_df = data_df.drop('Unnamed: 2', axis=1)
data_df = data_df.dropna()
data_df.tail()
# Out:
#                                 Name     Year  \
# 6   Nation - Public, 4-year or above  2011-12
# 7   Nation - Public, 4-year or above  2010-11
# 8   Nation - Public, 4-year or above  2009-10
# 9   Nation - Public, 4-year or above  2008-09
# 10  Nation - Public, 4-year or above  2007-08
#
#     Average amount of student loans received by full-time freshmen who borrowed  \
# 6                                              6336.0
# 7                                              6128.0
# 8                                              6070.0
# 9                                              6045.0
# 10                                             5182.0
#
#     Full-time freshmen who received any student loans (#)  \
# 6                                            555156.0
# 7                                            533227.0
# 8                                            509731.0
# 9                                            467676.0
# 10                                           438247.0
#
#     % of full-time freshmen who received any student loans  \
# 6                                                0.53
# 7                                                0.52
# 8                                                0.50
# 9                                                0.47
# 10                                               0.45
#
#     Per capita amount received in student loans by full-time freshmen    \
# 6                                              3358.0
# 7                                              3187.0
# 8                                              3035.0
# 9                                              2841.0
# 10                                             2332.0
#
#     Average debt of graduates  Percent of graduates with debt  \
# 6                     24477.0                            0.58
# 7                     23096.0                            0.57
# 8                     21604.0                            0.56
# 9                     20458.0                            0.56
# 10                    19082.0                            0.55
#
#     Per capita debt of graduates  Average debt of graduates in federal loans  \
# 6                        14222.0                                     21200.0
# 7                        13245.0                                     20014.0
# 8                        12049.0                                     18290.0
# 9                        11385.0                                     17157.0
# 10                       10487.0                                     16316.0
#
#     Percent of graduates borrowing federal loans  \
# 6                                           0.57
# 7                                           0.56
# 8                                           0.55
# 9                                           0.54
# 10                                          0.53
#
#     Federal debt of graduates, as percent of total debt  \
# 6                                                0.85
# 7                                                0.85
# 8                                                0.83
# 9                                                0.82
# 10                                               0.83
#
#     Nonfederal debt of graduates, as percent of total debt  \
# 6                                                0.15
# 7                                                0.15
# 8                                                0.17
# 9                                                0.18
# 10                                               0.17
#
#     Average percentage of need met of full-time undergraduates
# 6                                                0.66
# 7                                                0.67
# 8                                                0.69
# 9                                                0.70
# 10                                               0.70

# %% [markdown]
# # Data for 4 states: Minnesota,Washington, California, Massachusetts

# %%
data1_df = pd.read_csv("4statesData.csv")
data1_df = data1_df.dropna()
data1_df.head()
# Out:
#                                   Name     Year  \
# 1  Minnesota - Public, 4-year or above  2016-17
# 2  Minnesota - Public, 4-year or above  2015-16
# 3  Minnesota - Public, 4-year or above  2011-12
# 4  Minnesota - Public, 4-year or above  2012-13
# 5  Minnesota - Public, 4-year or above  2013-14
#
#    Average amount of student loans received by full-time freshmen who borrowed  \
# 1                                             8236.0
# 2                                             8103.0
# 3                                             7689.0
# 4                                             7556.0
# 5                                             7682.0
#
#    Full-time freshmen who received any student loans (#)  \
# 1                                             9933.0
# 2                                             9673.0
# 3                                            10826.0
# 4                                            10200.0
# 5                                            10140.0
#
#    % of full-time freshmen who received any student loans  \
# 1                                               0.60
# 2                                               0.60
# 3                                               0.64
# 4                                               0.62
# 5                                               0.62
#
#    Per capita amount received in student loans by full-time freshmen    \
# 1                                             4941.0
# 2                                             4862.0
# 3                                             4921.0
# 4                                             4685.0
# 5                                             4763.0
#
#    Average debt of graduates  Percent of graduates with debt  \
# 1                    29467.0                            0.68
# 2                    30091.0                            0.67
# 3                    29958.0                            0.69
# 4                    29657.0                            0.69
# 5                    29800.0                            0.69
#
#    Per capita debt of graduates  Average debt of graduates in federal loans  \
# 1                       20038.0                                     23095.0
# 2                       20161.0                                     23097.0
# 3                       20567.0                                     22611.0
# 4                       20566.0                                     22635.0
# 5                       20419.0                                     22965.0
#
#    Percent of graduates borrowing federal loans  \
# 1                                          0.66
# 2                                          0.66
# 3                                          0.67
# 4                                          0.65
# 5                                          0.67
#
#    Nonfederal debt of graduates, as percent of total debt  \
# 1                                               0.24
# 2                                               0.24
# 3                                               0.27
# 4                                               0.28
# 5                                               0.25
#
#    Average percentage of need met of full-time undergraduates
# 1                                               0.70
# 2                                               0.68
# 3                                               0.71
# 4                                               0.68
# 5                                               0.67

# %% [markdown]
# # Data for Minnesota

# %%
data3_df = pd.read_csv("MunnesotaData.csv")
data3_df = data3_df.dropna()
data3_df.head()
# Out:
#                                   Name     Year  \
# 1  Minnesota - Public, 4-year or above  2016-17
# 2  Minnesota - Public, 4-year or above  2015-16
# 3  Minnesota - Public, 4-year or above  2011-12
# 4  Minnesota - Public, 4-year or above  2012-13
# 5  Minnesota - Public, 4-year or above  2013-14
#
#    Average amount of student loans received by full-time freshmen who borrowed  \
# 1                                             8236.0
# 2                                             8103.0
# 3                                             7689.0
# 4                                             7556.0
# 5                                             7682.0
#
#    Full-time freshmen who received any student loans (#)  \
# 1                                             9933.0
# 2                                             9673.0
# 3                                            10826.0
# 4                                            10200.0
# 5                                            10140.0
#
#    % of full-time freshmen who received any student loans  \
# 1                                               0.60
# 2                                               0.60
# 3                                               0.64
# 4                                               0.62
# 5                                               0.62
#
#    Per capita amount received in student loans by full-time freshmen    \
# 1                                             4941.0
# 2                                             4862.0
# 3                                             4921.0
# 4                                             4685.0
# 5                                             4763.0
#
#    Average debt of graduates  Percent of graduates with debt  \
# 1                    29467.0                            0.68
# 2                    30091.0                            0.67
# 3                    29958.0                            0.69
# 4                    29657.0                            0.69
# 5                    29800.0                            0.69
#
#    Per capita debt of graduates  Average debt of graduates in federal loans  \
# 1                       20038.0                                     23095.0
# 2                       20161.0                                     23097.0
# 3                       20567.0                                     22611.0
# 4                       20566.0                                     22635.0
# 5                       20419.0                                     22965.0
#
#    Percent of graduates borrowing federal loans  \
# 1                                          0.66
# 2                                          0.66
# 3                                          0.67
# 4                                          0.65
# 5                                          0.67
#
#    Nonfederal debt of graduates, as percent of total debt  \
# 1                                               0.24
# 2                                               0.24
# 3                                               0.27
# 4                                               0.28
# 5                                               0.25
#
#    Average percentage of need met of full-time undergraduates
# 1                                               0.70
# 2                                               0.68
# 3                                               0.71
# 4                                               0.68
# 5                                               0.67

# %% [markdown]
# # Federal Student Loan Portfolio by Borrower Age.csv

# %%
data4_df = pd.read_csv("Portfolio-by-Age-Debt-Size (1).csv") 
data4_df.head()

data4_df.rename(columns = {'24 or Younger':'24 or Younger Dollars Outstanding (in billions)',
                              '24 - Younger':'24 or Younger Barrowers(#)(in millions)',
                              '25 to 34' : '25 to 34 Dollars Outstanding(in billions)',
                              '25 - 34' : '25 to 34 Younger Barrowers(#)(in millions)',
                              '35 to 49' : '35 to 49 Dollars Outstanding(in billions)',
                              '35 - 49' : '35 to 49 Younger Barrowers(#)(in millions)',
                              '50 to 61' : '50 to 61 Dollars Outstanding(in billions)',
                              '50 -61' : '50 to 61 Younger Barrowers(#)(in millions)',
                              '62 and Older' : '62+ Dollars Outstanding(in billions)',
                              '62 - Older' : '62+ Younger Barrowers(#)(in millions)'
                              }, inplace = True)
data4_df = data4_df.drop(data4_df.index[0])
data4_df.tail()
# Out:
#                 24 or Younger Dollars Outstanding (in billions)  \
# 5    40K to 60K                                          $10.07
# 6    60K to 80K                                           $3.97
# 7   80K to 100K                                           $2.32
# 8  100K to 200K                                           $5.47
# 9         200K+                                           $1.22
#
#   24 or Younger Barrowers(#)(in millions)  \
# 5                                    0.21
# 6                                    0.06
# 7                                    0.03
# 8                                    0.04
# 9                                    0.00
#
#   25 to 34 Dollars Outstanding(in billions)  \
# 5                                    $75.03
# 6                                    $56.47
# 7                                    $30.82
# 8                                    $80.48
# 9                                    $89.97
#
#   25 to 34 Younger Barrowers(#)(in millions)  \
# 5                                       1.54
# 6                                       0.82
# 7                                       0.35
# 8                                       0.58
# 9                                       0.30
#
#   35 to 49 Dollars Outstanding(in billions)  \
# 5                                    $79.68
# 6                                    $76.85
# 7                                    $55.84
# 8                                   $134.34
# 9                                    $90.97
#
#   35 to 49 Younger Barrowers(#)(in millions)  \
# 5                                       1.62
# 6                                       1.11
# 7                                       0.63
# 8                                       0.98
# 9                                       0.32
#
#   50 to 61 Dollars Outstanding(in billions)  \
# 5                                    $29.36
# 6                                    $27.99
# 7                                    $22.47
# 8                                    $62.57
# 9                                    $42.52
#
#   50 to 61 Younger Barrowers(#)(in millions)  \
# 5                                       0.60
# 6                                       0.40
# 7                                       0.25
# 8                                       0.45
# 9                                       0.15
#
#   62+ Dollars Outstanding(in billions) 62+ Younger Barrowers(#)(in millions)
# 5                                $8.72                                  0.18
# 6                                $7.92                                  0.11
# 7                                $6.42                                  0.07
# 8                               $18.83                                  0.14
# 9                               $15.16                                  0.05

# %% [markdown]
# # Portfolio-by-Location-by-Age.csv

# %%
data5_df = pd.read_csv("Portfolio-by-Location-by-Age.csv")
data5_df.rename(columns = {'24 - Younger':'24 or Younger Dollars Outstanding (in billions)',
                              'Unnamed: 2':'24 or Younger Barrowers(#)(in millions)',
                              '25 -34' : '25 to 34 Dollars Outstanding(in billions)',
                              'Unnamed: 4' : '25 to 34 Barrowers(#)(in millions)',
                              '35 - 49' : '35 to 49 Dollars Outstanding(in billions)',
                              'Unnamed: 6' : '35 to 49 Barrowers(#)(in millions)',
                              '50 -61' : '50 to 61 Dollars Outstanding(in billions)',
                              'Unnamed: 8' : '50 to 61 Barrowers(#)(in millions)',
                              '62 - Older' : '62+ Dollars Outstanding(in billions)',
                              'Unnamed: 10' : '62+  Barrowers(#)(in millions)'
                              }, inplace = True)

data5_df = data5_df.drop(data5_df.index[0])
data5_df.head()
data5_df = data5_df.reset_index()
data5_df.head()
# Out:
#    index             24 or Younger Dollars Outstanding (in billions)  \
# 0      1     Alabama                                           $1.78
# 1      2      Alaska                                           $0.12
# 2      3     Arizona                                           $1.75
# 3      4    Arkansas                                           $1.00
# 4      5  California                                           $9.67
#
#   24 or Younger Barrowers(#)(in millions)  \
# 0                                   120.7
# 1                                    10.5
# 2                                   133.9
# 3                                    74.3
# 4                                   700.4
#
#   25 to 34 Dollars Outstanding(in billions)  \
# 0                                     $7.03
# 1                                     $0.76
# 2                                     $9.33
# 3                                     $3.99
# 4                                    $50.17
#
#   25 to 34 Barrowers(#)(in millions)  \
# 0                              200.4
# 1                               25.4
# 2                              292.4
# 3                              128.0
# 4                            1,450.7
#
#   35 to 49 Dollars Outstanding(in billions)  \
# 0                                     $8.72
# 1                                     $0.86
# 2                                    $11.55
# 3                                     $4.86
# 4                                    $47.50
#
#   35 to 49 Barrowers(#)(in millions)  \
# 0                              182.0
# 1                               20.2
# 2                              263.1
# 3                              112.2
# 4                            1,023.5
#
#   50 to 61 Dollars Outstanding(in billions)  \
# 0                                     $3.15
# 1                                     $0.33
# 2                                     $4.51
# 3                                     $1.62
# 4                                    $20.74
#
#   50 to 61 Barrowers(#)(in millions) 62+ Dollars Outstanding(in billions)  \
# 0                               75.2                                $0.81
# 1                                7.8                                $0.10
# 2                              112.4                                $1.37
# 3                               42.6                                $0.41
# 4                              489.7                                $6.88
#
#   62+  Barrowers(#)(in millions)
# 0                           21.6
# 1                            2.3
# 2                           34.5
# 3                           11.3
# 4                          167.4

# %%
data5_df = data5_df[['index','Location','24 or Younger Dollars Outstanding (in billions)','24 or Younger Barrowers(#)(in millions)','25 to 34 Dollars Outstanding(in billions)','25 to 34 Barrowers(#)(in millions)','35 to 49 Dollars Outstanding(in billions)','35 to 49 Younger Barrowers(#)(in millions)','50 to 61 Dollars Outstanding(in billions)','50 to 61 Barrowers(#)(in millions)','62+ Dollars Outstanding(in billions)','62+ Barrowers(#)(in millions)']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-9c2ead8af587> in <module>
# ----> 1 data5_df = data5_df[['index','Location','24 or Younger Dollars Outstanding (in billions)','24 or Younger Barrowers(#)(in millions)','25 to 34 Dollars Outstanding(in billions)','25 to 34 Barrowers(#)(in millions)','35 to 49 Dollars Outstanding(in billions)','35 to 49 Younger Barrowers(#)(in millions)','50 to 61 Dollars Outstanding(in billions)','50 to 61 Barrowers(#)(in millions)','62+ Dollars Outstanding(in billions)','62+ Barrowers(#)(in millions)']]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['62+ Barrowers(#)(in millions)', 'Location', '35 to 49 Younger Barrowers(#)(in millions)'] not in index"

# %% [markdown]
# # Federal Student Loan Portfolio by Borrower Location

# %%
data7_df = pd.read_csv("Portfolio-by-Location.csv")
data7_df.head()
# Out:
#      Location  Balance (in billions)   Borrowers (in thousands)
# 0     Alabama                   $21.5                     600.3
# 1      Alaska                    $2.2                      66.2
# 2     Arizona                   $28.5                     836.6
# 3    Arkansas                   $11.9                     368.7
# 4  California                  $135.0                   3,834.5
